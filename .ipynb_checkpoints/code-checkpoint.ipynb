# %% [markdown]
# # INSY 695 Final Project
# ##### Group Members: Alice Liu, Corrine Jiang, Yi Kuang, Yichen Wang, Yulin Hong, Jingyu Chen, Kexin Wang, Xintong Li

# %% [markdown]
# ## 1. Environment Setup

# %% [markdown]
# ### 1.1 Load Packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.2 Load Spotify Dataset

# %%
data1 = pd.read_csv('https://raw.githubusercontent.com/gabminamedez/spotify-data/master/data.csv')

# %%
data1
# Out:
#                             id                                           name  \
# 0       6KbQ3uYMLKb5jDxLF7wYDD                    Singende Bataillone 1. Teil
# 1       6KuQTIu1KoTTkLXKrwlLPV       Fantasiestücke, Op. 111: Più tosto lento
# 2       6L63VW0PibdM1HDSBoqnoM                 Chapter 1.18 - Zamek kaniowski
# 3       6M94FkXd15sOAOQYRnWPN8  Bebamos Juntos - Instrumental (Remasterizado)
# 4       6N6tiFZ9vLTSOIxkj8qKrd    Polonaise-Fantaisie in A-Flat Major, Op. 61
# ...                        ...                                            ...
# 169904  4KppkflX7I3vJQk7urOJaS                  Skechers (feat. Tyga) - Remix
# 169905  1ehhGlTvjtHo2e4xJFB0SZ                 Sweeter (feat. Terrace Martin)
# 169906  52eycxprLhK3lPcRLbQiVk                               How Would I Know
# 169907  3wYOGJYD31sLRmBgCvWxa4                                    I Found You
# 169908  60RFlt48hm0l4Fu0JoccOl                          More Hearts Than Mine
#
#                                          artists  duration_ms release_date  \
# 0                            ['Carl Woitschach']       158648         1928
# 1       ['Robert Schumann', 'Vladimir Horowitz']       282133         1928
# 2                        ['Seweryn Goszczyński']       104300         1928
# 3                           ['Francisco Canaro']       180760      9/25/28
# 4       ['Frédéric Chopin', 'Vladimir Horowitz']       687733         1928
# ...                                          ...          ...          ...
# 169904                    ['DripReport', 'Tyga']       163800      5/15/20
# 169905        ['Leon Bridges', 'Terrace Martin']       167468       6/8/20
# 169906                     ['Kygo', 'Oh Wonder']       180700      5/29/20
# 169907             ['Cash Cash', 'Andy Grammer']       167308      2/28/20
# 169908                        ['Ingrid Andress']       214787      3/27/20
#
#         year  acousticness  danceability  energy  instrumentalness  liveness  \
# 0       1928        0.9950         0.708  0.1950          0.563000    0.1510
# 1       1928        0.9940         0.379  0.0135          0.901000    0.0763
# 2       1928        0.6040         0.749  0.2200          0.000000    0.1190
# 3       1928        0.9950         0.781  0.1300          0.887000    0.1110
# 4       1928        0.9900         0.210  0.2040          0.908000    0.0980
# ...      ...           ...           ...     ...               ...       ...
# 169904  2020        0.1730         0.875  0.4430          0.000032    0.0891
# 169905  2020        0.0167         0.719  0.3850          0.031300    0.1110
# 169906  2020        0.5380         0.514  0.5390          0.002330    0.1080
# 169907  2020        0.0714         0.646  0.7610          0.000000    0.2220
# 169908  2020        0.1090         0.512  0.4280          0.000000    0.1050
#
#         loudness  speechiness    tempo  valence  mode  key  popularity  \
# 0        -12.428       0.0506  118.469   0.7790     1   10           0
# 1        -28.454       0.0462   83.972   0.0767     1    8           0
# 2        -19.924       0.9290  107.177   0.8800     0    5           0
# 3        -14.734       0.0926  108.003   0.7200     0    1           0
# 4        -16.829       0.0424   62.149   0.0693     1   11           1
# ...          ...          ...      ...      ...   ...  ...         ...
# 169904    -7.461       0.1430  100.012   0.3060     1    1          75
# 169905   -10.907       0.0403  128.000   0.2700     1    8          64
# 169906    -9.332       0.1050  123.700   0.1530     1    7          70
# 169907    -2.557       0.0385  129.916   0.4720     1    1          70
# 169908    -7.387       0.0271   80.588   0.3660     1    0          65
#
#         explicit
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 169904         1
# 169905         0
# 169906         0
# 169907         0
# 169908         0
#
# [169909 rows x 19 columns]

# %% [markdown]
# ## 2. Data Pre-processing

# %% [markdown]
# ###2.1 Drop unnecessary columns

# %% [markdown]
# Column 'id' contains all unique values, which is not useful for machine larning. <br>
# Column 'release_date' contains information which is repeated in column 'year'.

# %%
data2 = data1.drop(columns=['id','release_date'])

# %%
data2
# Out:
#                                                  name  \
# 0                         Singende Bataillone 1. Teil
# 1            Fantasiestücke, Op. 111: Più tosto lento
# 2                      Chapter 1.18 - Zamek kaniowski
# 3       Bebamos Juntos - Instrumental (Remasterizado)
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61
# ...                                               ...
# 169904                  Skechers (feat. Tyga) - Remix
# 169905                 Sweeter (feat. Terrace Martin)
# 169906                               How Would I Know
# 169907                                    I Found You
# 169908                          More Hearts Than Mine
#
#                                          artists  duration_ms  year  \
# 0                            ['Carl Woitschach']       158648  1928
# 1       ['Robert Schumann', 'Vladimir Horowitz']       282133  1928
# 2                        ['Seweryn Goszczyński']       104300  1928
# 3                           ['Francisco Canaro']       180760  1928
# 4       ['Frédéric Chopin', 'Vladimir Horowitz']       687733  1928
# ...                                          ...          ...   ...
# 169904                    ['DripReport', 'Tyga']       163800  2020
# 169905        ['Leon Bridges', 'Terrace Martin']       167468  2020
# 169906                     ['Kygo', 'Oh Wonder']       180700  2020
# 169907             ['Cash Cash', 'Andy Grammer']       167308  2020
# 169908                        ['Ingrid Andress']       214787  2020
#
#         acousticness  danceability  energy  instrumentalness  liveness  \
# 0             0.9950         0.708  0.1950          0.563000    0.1510
# 1             0.9940         0.379  0.0135          0.901000    0.0763
# 2             0.6040         0.749  0.2200          0.000000    0.1190
# 3             0.9950         0.781  0.1300          0.887000    0.1110
# 4             0.9900         0.210  0.2040          0.908000    0.0980
# ...              ...           ...     ...               ...       ...
# 169904        0.1730         0.875  0.4430          0.000032    0.0891
# 169905        0.0167         0.719  0.3850          0.031300    0.1110
# 169906        0.5380         0.514  0.5390          0.002330    0.1080
# 169907        0.0714         0.646  0.7610          0.000000    0.2220
# 169908        0.1090         0.512  0.4280          0.000000    0.1050
#
#         loudness  speechiness    tempo  valence  mode  key  popularity  \
# 0        -12.428       0.0506  118.469   0.7790     1   10           0
# 1        -28.454       0.0462   83.972   0.0767     1    8           0
# 2        -19.924       0.9290  107.177   0.8800     0    5           0
# 3        -14.734       0.0926  108.003   0.7200     0    1           0
# 4        -16.829       0.0424   62.149   0.0693     1   11           1
# ...          ...          ...      ...      ...   ...  ...         ...
# 169904    -7.461       0.1430  100.012   0.3060     1    1          75
# 169905   -10.907       0.0403  128.000   0.2700     1    8          64
# 169906    -9.332       0.1050  123.700   0.1530     1    7          70
# 169907    -2.557       0.0385  129.916   0.4720     1    1          70
# 169908    -7.387       0.0271   80.588   0.3660     1    0          65
#
#         explicit
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 169904         1
# 169905         0
# 169906         0
# 169907         0
# 169908         0
#
# [169909 rows x 17 columns]

# %% [markdown]
# ###2.2 Data Structure and Value Exploration

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169909 entries, 0 to 169908
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              169909 non-null  object
#  1   artists           169909 non-null  object
#  2   duration_ms       169909 non-null  int64
#  3   year              169909 non-null  int64
#  4   acousticness      169909 non-null  float64
#  5   danceability      169909 non-null  float64
#  6   energy            169909 non-null  float64
#  7   instrumentalness  169909 non-null  float64
#  8   liveness          169909 non-null  float64
#  9   loudness          169909 non-null  float64
#  10  speechiness       169909 non-null  float64
#  11  tempo             169909 non-null  float64
#  12  valence           169909 non-null  float64
#  13  mode              169909 non-null  int64
#  14  key               169909 non-null  int64
#  15  popularity        169909 non-null  int64
#  16  explicit          169909 non-null  int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 22.0+ MB

# %%
data2.describe()
# Out:
#         duration_ms           year   acousticness   danceability  \
# count  1.699090e+05  169909.000000  169909.000000  169909.000000
# mean   2.314062e+05    1977.223231       0.493214       0.538150
# std    1.213219e+05      25.593168       0.376627       0.175346
# min    5.108000e+03    1921.000000       0.000000       0.000000
# 25%    1.710400e+05    1957.000000       0.094500       0.417000
# 50%    2.086000e+05    1978.000000       0.492000       0.548000
# 75%    2.629600e+05    1999.000000       0.888000       0.667000
# max    5.403500e+06    2020.000000       0.996000       0.988000
#
#               energy  instrumentalness       liveness       loudness  \
# count  169909.000000     169909.000000  169909.000000  169909.000000
# mean        0.488593          0.161937       0.206690     -11.370289
# std         0.267390          0.309329       0.176796       5.666765
# min         0.000000          0.000000       0.000000     -60.000000
# 25%         0.263000          0.000000       0.098400     -14.470000
# 50%         0.481000          0.000204       0.135000     -10.474000
# 75%         0.710000          0.086800       0.263000      -7.118000
# max         1.000000          1.000000       1.000000       3.855000
#
#          speechiness          tempo        valence           mode  \
# count  169909.000000  169909.000000  169909.000000  169909.000000
# mean        0.094058     116.948017       0.532095       0.708556
# std         0.149937      30.726937       0.262408       0.454429
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.034900      93.516000       0.322000       0.000000
# 50%         0.045000     114.778000       0.544000       1.000000
# 75%         0.075400     135.712000       0.749000       1.000000
# max         0.969000     244.091000       1.000000       1.000000
#
#                  key     popularity       explicit
# count  169909.000000  169909.000000  169909.000000
# mean        5.200519      31.556610       0.084863
# std         3.515257      21.582614       0.278679
# min         0.000000       0.000000       0.000000
# 25%         2.000000      12.000000       0.000000
# 50%         5.000000      33.000000       0.000000
# 75%         8.000000      48.000000       0.000000
# max        11.000000     100.000000       1.000000

# %% [markdown]
# We see that this is a fairly clean dataset mainly consisted of numeric values, which is ideal for data learning (regression, clustering, etc.).

# %% [markdown]
# ###2.3 Create New Columns

# %% [markdown]
# We want to create a column that contains data on number of artists.

# %%
data2['NumArtists'] = pd.Series(dtype='int')
for i in range(data2.shape[0]):
  string = data2['artists'][i]
  string = string[1:len(string)-1]
  string = string.split(',')
  data2['NumArtists'][i] = int(len(string))
# Out:
# <ipython-input-20-8eea2ed94fce>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['NumArtists'][i] = int(len(string))

# %%
data2
# Out:
#                                                  name  \
# 0                         Singende Bataillone 1. Teil
# 1            Fantasiestücke, Op. 111: Più tosto lento
# 2                      Chapter 1.18 - Zamek kaniowski
# 3       Bebamos Juntos - Instrumental (Remasterizado)
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61
# ...                                               ...
# 169904                  Skechers (feat. Tyga) - Remix
# 169905                 Sweeter (feat. Terrace Martin)
# 169906                               How Would I Know
# 169907                                    I Found You
# 169908                          More Hearts Than Mine
#
#                                          artists  duration_ms  year  \
# 0                            ['Carl Woitschach']       158648  1928
# 1       ['Robert Schumann', 'Vladimir Horowitz']       282133  1928
# 2                        ['Seweryn Goszczyński']       104300  1928
# 3                           ['Francisco Canaro']       180760  1928
# 4       ['Frédéric Chopin', 'Vladimir Horowitz']       687733  1928
# ...                                          ...          ...   ...
# 169904                    ['DripReport', 'Tyga']       163800  2020
# 169905        ['Leon Bridges', 'Terrace Martin']       167468  2020
# 169906                     ['Kygo', 'Oh Wonder']       180700  2020
# 169907             ['Cash Cash', 'Andy Grammer']       167308  2020
# 169908                        ['Ingrid Andress']       214787  2020
#
#         acousticness  danceability  energy  instrumentalness  liveness  \
# 0             0.9950         0.708  0.1950          0.563000    0.1510
# 1             0.9940         0.379  0.0135          0.901000    0.0763
# 2             0.6040         0.749  0.2200          0.000000    0.1190
# 3             0.9950         0.781  0.1300          0.887000    0.1110
# 4             0.9900         0.210  0.2040          0.908000    0.0980
# ...              ...           ...     ...               ...       ...
# 169904        0.1730         0.875  0.4430          0.000032    0.0891
# 169905        0.0167         0.719  0.3850          0.031300    0.1110
# 169906        0.5380         0.514  0.5390          0.002330    0.1080
# 169907        0.0714         0.646  0.7610          0.000000    0.2220
# 169908        0.1090         0.512  0.4280          0.000000    0.1050
#
#         loudness  speechiness    tempo  valence  mode  key  popularity  \
# 0        -12.428       0.0506  118.469   0.7790     1   10           0
# 1        -28.454       0.0462   83.972   0.0767     1    8           0
# 2        -19.924       0.9290  107.177   0.8800     0    5           0
# 3        -14.734       0.0926  108.003   0.7200     0    1           0
# 4        -16.829       0.0424   62.149   0.0693     1   11           1
# ...          ...          ...      ...      ...   ...  ...         ...
# 169904    -7.461       0.1430  100.012   0.3060     1    1          75
# 169905   -10.907       0.0403  128.000   0.2700     1    8          64
# 169906    -9.332       0.1050  123.700   0.1530     1    7          70
# 169907    -2.557       0.0385  129.916   0.4720     1    1          70
# 169908    -7.387       0.0271   80.588   0.3660     1    0          65
#
#         explicit  NumArtists
# 0              0         1.0
# 1              0         2.0
# 2              0         1.0
# 3              0         1.0
# 4              0         2.0
# ...          ...         ...
# 169904         1         2.0
# 169905         0         2.0
# 169906         0         2.0
# 169907         0         2.0
# 169908         0         1.0
#
# [169909 rows x 18 columns]

# %% [markdown]
# We also want to create a column about the name length of a song.

# %%
data2['NameLength'] = pd.Series(dtype='int')
for i in range(data2.shape[0]):
  n = len(data2['name'][i].split())
  data2['NameLength'][i] = int(n)
# Out:
# <ipython-input-22-9b80a7446bf9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['NameLength'][i] = int(n)

# %%
data2
# Out:
#                                                  name  \
# 0                         Singende Bataillone 1. Teil
# 1            Fantasiestücke, Op. 111: Più tosto lento
# 2                      Chapter 1.18 - Zamek kaniowski
# 3       Bebamos Juntos - Instrumental (Remasterizado)
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61
# ...                                               ...
# 169904                  Skechers (feat. Tyga) - Remix
# 169905                 Sweeter (feat. Terrace Martin)
# 169906                               How Would I Know
# 169907                                    I Found You
# 169908                          More Hearts Than Mine
#
#                                          artists  duration_ms  year  \
# 0                            ['Carl Woitschach']       158648  1928
# 1       ['Robert Schumann', 'Vladimir Horowitz']       282133  1928
# 2                        ['Seweryn Goszczyński']       104300  1928
# 3                           ['Francisco Canaro']       180760  1928
# 4       ['Frédéric Chopin', 'Vladimir Horowitz']       687733  1928
# ...                                          ...          ...   ...
# 169904                    ['DripReport', 'Tyga']       163800  2020
# 169905        ['Leon Bridges', 'Terrace Martin']       167468  2020
# 169906                     ['Kygo', 'Oh Wonder']       180700  2020
# 169907             ['Cash Cash', 'Andy Grammer']       167308  2020
# 169908                        ['Ingrid Andress']       214787  2020
#
#         acousticness  danceability  energy  instrumentalness  liveness  \
# 0             0.9950         0.708  0.1950          0.563000    0.1510
# 1             0.9940         0.379  0.0135          0.901000    0.0763
# 2             0.6040         0.749  0.2200          0.000000    0.1190
# 3             0.9950         0.781  0.1300          0.887000    0.1110
# 4             0.9900         0.210  0.2040          0.908000    0.0980
# ...              ...           ...     ...               ...       ...
# 169904        0.1730         0.875  0.4430          0.000032    0.0891
# 169905        0.0167         0.719  0.3850          0.031300    0.1110
# 169906        0.5380         0.514  0.5390          0.002330    0.1080
# 169907        0.0714         0.646  0.7610          0.000000    0.2220
# 169908        0.1090         0.512  0.4280          0.000000    0.1050
#
#         loudness  speechiness    tempo  valence  mode  key  popularity  \
# 0        -12.428       0.0506  118.469   0.7790     1   10           0
# 1        -28.454       0.0462   83.972   0.0767     1    8           0
# 2        -19.924       0.9290  107.177   0.8800     0    5           0
# 3        -14.734       0.0926  108.003   0.7200     0    1           0
# 4        -16.829       0.0424   62.149   0.0693     1   11           1
# ...          ...          ...      ...      ...   ...  ...         ...
# 169904    -7.461       0.1430  100.012   0.3060     1    1          75
# 169905   -10.907       0.0403  128.000   0.2700     1    8          64
# 169906    -9.332       0.1050  123.700   0.1530     1    7          70
# 169907    -2.557       0.0385  129.916   0.4720     1    1          70
# 169908    -7.387       0.0271   80.588   0.3660     1    0          65
#
#         explicit  NumArtists  NameLength
# 0              0         1.0         4.0
# 1              0         2.0         6.0
# 2              0         1.0         5.0
# 3              0         1.0         5.0
# 4              0         2.0         6.0
# ...          ...         ...         ...
# 169904         1         2.0         5.0
# 169905         0         2.0         4.0
# 169906         0         2.0         4.0
# 169907         0         2.0         3.0
# 169908         0         1.0         4.0
#
# [169909 rows x 19 columns]

# %% [markdown]
# We then discard column 'name' and 'artists', as they are no longer useful.

# %%
data = data2.drop(columns = ['name','artists'])

# %%
data
# Out:
#         duration_ms  year  acousticness  danceability  energy  \
# 0            158648  1928        0.9950         0.708  0.1950
# 1            282133  1928        0.9940         0.379  0.0135
# 2            104300  1928        0.6040         0.749  0.2200
# 3            180760  1928        0.9950         0.781  0.1300
# 4            687733  1928        0.9900         0.210  0.2040
# ...             ...   ...           ...           ...     ...
# 169904       163800  2020        0.1730         0.875  0.4430
# 169905       167468  2020        0.0167         0.719  0.3850
# 169906       180700  2020        0.5380         0.514  0.5390
# 169907       167308  2020        0.0714         0.646  0.7610
# 169908       214787  2020        0.1090         0.512  0.4280
#
#         instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0               0.563000    0.1510   -12.428       0.0506  118.469   0.7790
# 1               0.901000    0.0763   -28.454       0.0462   83.972   0.0767
# 2               0.000000    0.1190   -19.924       0.9290  107.177   0.8800
# 3               0.887000    0.1110   -14.734       0.0926  108.003   0.7200
# 4               0.908000    0.0980   -16.829       0.0424   62.149   0.0693
# ...                  ...       ...       ...          ...      ...      ...
# 169904          0.000032    0.0891    -7.461       0.1430  100.012   0.3060
# 169905          0.031300    0.1110   -10.907       0.0403  128.000   0.2700
# 169906          0.002330    0.1080    -9.332       0.1050  123.700   0.1530
# 169907          0.000000    0.2220    -2.557       0.0385  129.916   0.4720
# 169908          0.000000    0.1050    -7.387       0.0271   80.588   0.3660
#
#         mode  key  popularity  explicit  NumArtists  NameLength
# 0          1   10           0         0         1.0         4.0
# 1          1    8           0         0         2.0         6.0
# 2          0    5           0         0         1.0         5.0
# 3          0    1           0         0         1.0         5.0
# 4          1   11           1         0         2.0         6.0
# ...      ...  ...         ...       ...         ...         ...
# 169904     1    1          75         1         2.0         5.0
# 169905     1    8          64         0         2.0         4.0
# 169906     1    7          70         0         2.0         4.0
# 169907     1    1          70         0         2.0         3.0
# 169908     1    0          65         0         1.0         4.0
#
# [169909 rows x 17 columns]

# %% [markdown]
#  let's check to see if there are any duplicate rows that might skew our data a certain way:

# %%
data[data.duplicated()]
# Out:
#         duration_ms  year  acousticness  danceability  energy  \
# 609           61467  1945       0.98300         0.635  0.0123
# 652         1325093  1945       0.91300         0.704  0.2230
# 3344         260333  1972       0.12800         0.591  0.6370
# 8094         230040  2020       0.46000         0.591  0.6590
# 8169         491333  1928       0.99300         0.303  0.2260
# ...             ...   ...           ...           ...     ...
# 164200       164467  1963       0.83800         0.493  0.2170
# 166015       262147  1982       0.21300         0.291  0.9750
# 168041       179773  2002       0.04210         0.625  0.9250
# 169035       281947  2012       0.80600         0.390  0.2550
# 169219       231000  2014       0.00245         0.588  0.7910
#
#         instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 609             0.955000    0.1070   -27.297       0.0521   83.046    0.610
# 652             0.000000    0.3260   -24.480       0.9350  112.485    0.403
# 3344            0.019500    0.0989    -9.102       0.0887  172.452    0.962
# 8094            0.000000    0.3240    -5.464       0.0332  145.997    0.622
# 8169            0.826000    0.1190   -21.483       0.0444   67.013    0.146
# ...                  ...       ...       ...          ...      ...      ...
# 164200          0.004630    0.0867   -11.501       0.0271  105.003    0.182
# 166015          0.908000    0.3320   -10.754       0.0557  180.289    0.127
# 168041          0.000000    0.8650    -4.435       0.3420  172.017    0.515
# 169035          0.000001    0.0887    -9.676       0.0299  122.056    0.179
# 169219          0.002580    0.1180    -5.595       0.0402   94.933    0.487
#
#         mode  key  popularity  explicit  NumArtists  NameLength
# 609        1    0           0         0         3.0        14.0
# 652        0    2           0         0         1.0         4.0
# 3344       0    5          26         0         1.0         6.0
# 8094       1   11           2         0         1.0         4.0
# 8169       1    3           0         0         2.0         7.0
# ...      ...  ...         ...       ...         ...         ...
# 164200     1    9          20         0         1.0         2.0
# 166015     0    6          33         0         1.0         5.0
# 168041     1    0          47         0         1.0         1.0
# 169035     0    6          50         0         1.0         4.0
# 169219     1    7          56         0         1.0         1.0
#
# [649 rows x 17 columns]

# %% [markdown]
# Hence drop the duplicated rows

# %%
data.drop_duplicates(inplace=True)
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [duration_ms, year, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, valence, mode, key, popularity, explicit, NumArtists, NameLength]
# Index: []

# %% [markdown]
# Hence, we've finished the data preprosessing.

# %% [markdown]
# #**data exploration**

# %% [markdown]
# Correlations (Check top 10 positive and negative correlations)

# %%
corr = data.corr()['popularity'].sort_values()

# Display correlations
print('Top 10 - Positive Correlations:')
print('-----------------------------------')
print(corr.tail(10))
print('\nTop 10 - Negative Correlations:')
print('------------------------------')
print(corr.head(10))
# Out:
# Top 10 - Positive Correlations:
# -----------------------------------
# valence         0.005033
# key             0.011052
# duration_ms     0.063238
# tempo           0.133543
# explicit        0.213450
# danceability    0.217697
# loudness        0.463656
# energy          0.495026
# year            0.880401
# popularity      1.000000
# Name: popularity, dtype: float64
#
# Top 10 - Negative Correlations:
# ------------------------------
# acousticness       -0.591012
# instrumentalness   -0.295625
# NameLength         -0.273048
# NumArtists         -0.159573
# speechiness        -0.137648
# liveness           -0.075998
# mode               -0.033346
# valence             0.005033
# key                 0.011052
# duration_ms         0.063238
# Name: popularity, dtype: float64

# %% [markdown]
# Correlation matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(17,17))
sns.heatmap(data.corr(),annot=True,cmap='Blues')
b,t=plt.ylim()
b+=0.5
t-=0.5
plt.ylim(b,t)
plt.show()

# %% [markdown]
# Distribution of discrete features

# %%
discrete_cols = data[['mode','key', 'explicit', 'NumArtists', 'NameLength']]
for i in discrete_cols:
    plt.figure(figsize=(20,5))
    plt.subplot(131)
    sns.countplot(data[i])
    plt.title(i+' Distribution')
# Out:
# /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Distribution of continuous features

# %%
continuous_cols = data.drop(columns = ['mode','key', 'explicit', 'NumArtists', 'NameLength'])
for i in continuous_cols:
    plt.figure(figsize=(20,5))
    
    plt.subplot(131)
    sns.kdeplot(data[i],color='b',shade=True)
    plt.title(i+' Distribution')

# %% [markdown]
# Before starting to construct the models, we need to detect if there exists the heteroskedasticity problem. Otherwise the inconsistency of a variance can cause the linear regression model to have high bias.

# %%
data.head(5)
# Out:
#    duration_ms  year  acousticness  danceability  energy  instrumentalness  \
# 0       158648  1928         0.995         0.708  0.1950             0.563
# 1       282133  1928         0.994         0.379  0.0135             0.901
# 2       104300  1928         0.604         0.749  0.2200             0.000
# 3       180760  1928         0.995         0.781  0.1300             0.887
# 4       687733  1928         0.990         0.210  0.2040             0.908
#
#    liveness  loudness  speechiness    tempo  valence  mode  key  popularity  \
# 0    0.1510   -12.428       0.0506  118.469   0.7790     1   10           0
# 1    0.0763   -28.454       0.0462   83.972   0.0767     1    8           0
# 2    0.1190   -19.924       0.9290  107.177   0.8800     0    5           0
# 3    0.1110   -14.734       0.0926  108.003   0.7200     0    1           0
# 4    0.0980   -16.829       0.0424   62.149   0.0693     1   11           1
#
#    explicit  NumArtists  NameLength
# 0         0         1.0         4.0
# 1         0         2.0         6.0
# 2         0         1.0         5.0
# 3         0         1.0         5.0
# 4         0         2.0         6.0

# %%
x = data.drop(columns = ['popularity'])
y = data['popularity']

# %%
for i in x:
  plt.figure()
  plt.title(i + ' vs popularity')
  plt.scatter(data[i], y)
  plt.ylabel('popularity')

# %% [markdown]
# According to the graphs above, there is no obvious horn shape figures existing. Thus we conclude that the heteroscedasticity does not exist in our dataset.

# %% [markdown]
# **Check how the trend of music evolves throughout the years**

# %%
sp1, elements = plt.subplots(3, 2) # Initiate the subplots

arrElements = ["acousticness", "danceability", "energy", "instrumentalness", "speechiness", "valence"]
row = 0
col = 0

for elem in arrElements: # Produce a line graph for each musical element
    data.groupby("year")[elem].mean().plot(ax=elements[row][col], figsize=(30,20)) # Group rows by year and get the mean values for that particular element
    elements[row][col].set_xlabel("decade")
    elements[row][col].set_ylabel(elem)
    if col == 0:
        col = 1
    elif row == 0 and col == 1:
        row = 1
        col = 0
    elif row == 1 and col == 1:
        row = 2
        col = 0

# %% [markdown]
# Explore the relationship between music elements and mode-key combination

# %%
df = data.groupby(["mode", "key"]).agg("mean")
for i in range(2): # Loop through each unique value for the mode variable
    mode_df = data.query("mode == @i") # Filter df to only contain tracks of the present mode
    for j in range (12): # Loop through each unique value for key variable
        modekey_df = mode_df.query("key == @j") # Filter df to only contain tracks of the present key, partnered with the present mode acquired in the parent loop

mode_key = []
for i in range(2):
  for j in range(12):
    mode_key.append(str(i)+"_"+str(j))

df.insert(loc=0, column="count", value=data.groupby(["mode", "key"]).size())
df.insert(loc=0,column="mode-key",value =mode_key)
df
# Out:
#          mode-key  count    duration_ms         year  acousticness  \
# mode key
# 0    0        0_0   4104  241814.671296  1974.005604      0.575527
#      1        0_1   3353  230051.904265  1986.000000      0.375331
#      2        0_2   4081  240866.542514  1972.367557      0.584801
#      3        0_3   1577  229016.937857  1973.753963      0.530122
#      4        0_4   5533  247604.153985  1980.461594      0.428093
#      5        0_5   5515  243508.683953  1975.594923      0.515105
#      6        0_6   3598  235844.335464  1985.150639      0.363554
#      7        0_7   4038  239005.468549  1973.505696      0.592619
#      8        0_8   1964  234352.020876  1981.846232      0.459607
#      9        0_9   5640  241023.910638  1978.332092      0.464635
#      10      0_10   4224  251929.951705  1980.149148      0.412953
#      11      0_11   5676  234933.035412  1982.604827      0.328354
# 1    0        1_0  17325  228432.836364  1976.763232      0.490800
#      1        1_1   9419  234001.164455  1980.452914      0.443476
#      2        1_2  14676  233158.623808  1979.226288      0.439596
#      3        1_3   5559  225865.283864  1967.269653      0.706653
#      4        1_4   7339  220946.767680  1978.033792      0.494523
#      5        1_5  10762  226203.864337  1972.187883      0.602216
#      6        1_6   4951  225796.030297  1979.122400      0.479272
#      7        1_7  16655  225998.055359  1977.762774      0.465503
#      8        1_8   8702  229606.200758  1975.144909      0.549105
#      9        1_9  11940  226481.263400  1979.177303      0.427484
#      10      1_10   7758  222306.331915  1971.620263      0.636513
#      11      1_11   4871  229325.944980  1981.240608      0.454613
#
#           danceability    energy  instrumentalness  liveness   loudness  \
# mode key
# 0    0        0.527936  0.433967          0.216107  0.198846 -12.281273
#      1        0.569423  0.570454          0.150113  0.200633 -10.056370
#      2        0.506301  0.434437          0.225921  0.198014 -12.414224
#      3        0.535558  0.472635          0.193457  0.201049 -11.640042
#      4        0.526600  0.531172          0.174632  0.212854 -11.026183
#      5        0.559677  0.481850          0.184115  0.207433 -11.512655
#      6        0.578844  0.566342          0.133159  0.211415 -10.067949
#      7        0.530618  0.439735          0.218545  0.199470 -11.997616
#      8        0.568026  0.521587          0.183861  0.200716 -10.763674
#      9        0.539649  0.499157          0.179010  0.191066 -11.417224
#      10       0.588256  0.527620          0.169239  0.208416 -11.054968
#      11       0.585157  0.570780          0.123233  0.222596 -10.384183
# 1    0        0.539512  0.477037          0.148532  0.211026 -11.485170
#      1        0.560154  0.498222          0.155239  0.201057 -11.199615
#      2        0.530761  0.523933          0.142781  0.212671 -10.904652
#      3        0.491725  0.374665          0.216881  0.188778 -12.828672
#      4        0.526653  0.499220          0.136393  0.216277 -11.150782
#      5        0.519747  0.426832          0.178815  0.206187 -12.241275
#      6        0.543690  0.495624          0.155391  0.202699 -11.102518
#      7        0.543025  0.496877          0.141700  0.218424 -11.315423
#      8        0.531526  0.461450          0.169538  0.190030 -11.565622
#      9        0.532421  0.540750          0.125746  0.208310 -10.567112
#      10       0.520644  0.414103          0.171062  0.195922 -12.155121
#      11       0.542940  0.521498          0.147061  0.214422 -10.757488
#
#           speechiness       tempo   valence  popularity  explicit  NumArtists  \
# mode key
# 0    0       0.082894  114.943113  0.502828   29.266569  0.073587    1.377437
#      1       0.112961  117.873621  0.523986   38.315240  0.182523    1.331942
#      2       0.082840  115.285976  0.491515   27.642490  0.057094    1.429552
#      3       0.132206  114.517158  0.508220   28.881420  0.105897    1.370958
#      4       0.088083  116.506076  0.492917   34.316646  0.106091    1.324236
#      5       0.105773  115.904041  0.549527   30.520399  0.107344    1.322393
#      6       0.121782  116.717507  0.547434   37.772651  0.178432    1.328794
#      7       0.075122  115.710164  0.523864   28.877662  0.057949    1.380634
#      8       0.109707  115.384345  0.541321   34.676171  0.161405    1.362016
#      9       0.084846  117.539580  0.525749   33.020035  0.071454    1.279255
#      10      0.153072  113.643947  0.542612   33.792140  0.185843    1.387784
#      11      0.157192  118.939710  0.561829   35.539464  0.196794    1.274313
# 1    0       0.089767  117.596937  0.541179   31.309149  0.066436    1.302107
#      1       0.137266  115.290769  0.502558   33.674912  0.182716    1.404608
#      2       0.082262  118.960272  0.537793   33.202916  0.067389    1.311870
#      3       0.068454  115.455139  0.502987   23.467710  0.018349    1.481382
#      4       0.073741  118.830395  0.544185   32.499796  0.042513    1.262025
#      5       0.076038  115.438318  0.531392   27.742706  0.032429    1.375023
#      6       0.115798  115.033079  0.516220   32.799838  0.105231    1.296708
#      7       0.089433  117.691896  0.551835   31.989853  0.074812    1.298049
#      8       0.091166  116.257405  0.522330   29.817513  0.077453    1.360377
#      9       0.080006  120.751302  0.561848   33.335092  0.053099    1.241876
#      10      0.069929  114.985907  0.534367   27.058262  0.028229    1.410673
#      11      0.099450  116.668863  0.526467   34.126668  0.103264    1.298707
#
#           NameLength
# mode key
# 0    0      4.553363
#      1      4.134506
#      2      4.638814
#      3      4.410273
#      4      4.220495
#      5      4.314597
#      6      4.026404
#      7      4.519564
#      8      4.012220
#      9      4.292730
#      10     4.514205
#      11     4.108175
# 1    0      4.519827
#      1      4.344092
#      2      4.375443
#      3      4.940457
#      4      4.389426
#      5      4.683702
#      6      4.266411
#      7      4.478835
#      8      4.377959
#      9      4.370938
#      10     4.804847
#      11     4.111476

# %% [markdown]
# Rank the number to find the most and least popular key_mode combination and analyze their music elements

# %%
df['count'].rank(ascending=False)
# Out:
# mode  key
# 0     0      18.0
#       1      22.0
#       2      19.0
#       3      24.0
#       4      13.0
#       5      14.0
#       6      21.0
#       7      20.0
#       8      23.0
#       9      11.0
#       10     17.0
#       11     10.0
# 1     0       1.0
#       1       6.0
#       2       3.0
#       3      12.0
#       4       9.0
#       5       5.0
#       6      15.0
#       7       2.0
#       8       7.0
#       9       4.0
#       10      8.0
#       11     16.0
# Name: count, dtype: float64

# %% [markdown]
# key-mode: 0,1 (C major is the most popular):

# %%
print(data.query("mode == 1 and key == 0").mean())
print("------------------------------------------------")
print(data.mean())
# Out:
# duration_ms         228432.836364
# year                  1976.763232
# acousticness             0.490800
# danceability             0.539512
# energy                   0.477037
# instrumentalness         0.148532
# liveness                 0.211026
# loudness               -11.485170
# speechiness              0.089767
# tempo                  117.596937
# valence                  0.541179
# mode                     1.000000
# key                      0.000000
# popularity              31.309149
# explicit                 0.066436
# NumArtists               1.302107
# NameLength               4.519827
# dtype: float64
# ------------------------------------------------
# duration_ms         231434.725257
# year                  1977.339230
# acousticness             0.491646
# danceability             0.538725
# energy                   0.489606
# instrumentalness         0.160446
# liveness                 0.206727
# loudness               -11.342429
# speechiness              0.094200
# tempo                  116.995304
# valence                  0.532917
# mode                     0.708714
# key                      5.199675
# popularity              31.665526
# explicit                 0.085147
# NumArtists               1.331608
# NameLength               4.428837
# dtype: float64

# %% [markdown]
# Most of the C-major songs are in the 70s where it is danceable and energetic.

# %% [markdown]
# ## Clustering

# %%
data.head()
# Out:
#    duration_ms  year  acousticness  danceability  energy  instrumentalness  \
# 0       158648  1928         0.995         0.708  0.1950             0.563
# 1       282133  1928         0.994         0.379  0.0135             0.901
# 2       104300  1928         0.604         0.749  0.2200             0.000
# 3       180760  1928         0.995         0.781  0.1300             0.887
# 4       687733  1928         0.990         0.210  0.2040             0.908
#
#    liveness  loudness  speechiness    tempo  valence  mode  key  popularity  \
# 0    0.1510   -12.428       0.0506  118.469   0.7790     1   10           0
# 1    0.0763   -28.454       0.0462   83.972   0.0767     1    8           0
# 2    0.1190   -19.924       0.9290  107.177   0.8800     0    5           0
# 3    0.1110   -14.734       0.0926  108.003   0.7200     0    1           0
# 4    0.0980   -16.829       0.0424   62.149   0.0693     1   11           1
#
#    explicit  NumArtists  NameLength
# 0         0         1.0         4.0
# 1         0         2.0         6.0
# 2         0         1.0         5.0
# 3         0         1.0         5.0
# 4         0         2.0         6.0

# %%
X = data.drop(columns='popularity')
y = data['popularity']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %% [markdown]
# ### all

# %% [markdown]
# ### K-means

# %%
############use Elbow method to find optimal k##########
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples
from sklearn.metrics import silhouette_score

from tqdm import tqdm
withinss = []
results = []
for i in tqdm(range(2,8)):
    kmeans = KMeans(n_clusters = i)
    model = kmeans.fit(X_std)
    labels = model.labels_
    withinss.append(model.inertia_)
    results.append(silhouette_score(X_std, labels))
# Out:
# 100%|██████████| 6/6 [30:35<00:00, 305.84s/it]

# %%
from matplotlib import pyplot
print("Hi, please run the following two lines sepearately!!!!!!!  ;)")
#1
pyplot.plot([2,3,4,5,6,7],withinss)
print("Dear TA, please run these following two lines sepearately, otherwise its hard to see the second picture's shapem!!!!!!")
# Out:
# Hi, please run the following two lines sepearately!!!!!!!  ;)
# Dear TA, please run these following two lines sepearately, otherwise its hard to see the second picture's shapem!!!!!!

# %%
pyplot.plot([2,3,4,5,6,7],results) 
print("From the second graph we can see, Silhouette score drops dramatically after k=2, so I decided to use k=2")
# Out:
# From the second graph we can see, Silhouette score drops dramatically after k=2, so I decided to use k=2

# %%
#use selected features to build k-Means model
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 2)
model = kmeans.fit(X_std)
labels = model.labels_
labels

from sklearn.metrics import silhouette_samples
silhouette_samples(X_std, labels)

from sklearn.metrics import silhouette_score
silhouette_score(X_std, labels)

#count how many are in first cluster and how many in second
l1 = []
l0 = []
l2 = []
for i in range(len(labels)):
    if labels[i] == 1:
        l1.append(labels[i])
    if labels[i] == 2:
        l2.append(labels[i])
    else:
        l0.append(labels[i])
        
print("There are "+ str(len(l1)) + " numbers in the first cluster")
print("There are "+ str(len(l0))+" numbers in the second cluster")
print("There are "+ str(len(l2))+" numbers in the third cluster")

#find the cluster center's characteristics
centers = model.cluster_centers_
print(centers)
# Out:
# There are 72331 numbers in the first cluster
# There are 169260 numbers in the second cluster
# There are 0 numbers in the third cluster
# [[ 0.04310883  0.573503   -0.67710359  0.29285312  0.66936949 -0.3197573
#   -0.00366657  0.57193781 -0.07944985  0.2042533   0.26688086 -0.02450216
#    0.02857677  0.14964402 -0.18431464 -0.2465774 ]
#  [-0.05765346 -0.76699908  0.90555382 -0.3916598  -0.89521028  0.42764128
#    0.00490364 -0.76490581  0.1062557  -0.273167   -0.35692468  0.03276903
#   -0.03821838 -0.20013292  0.24650117  0.32977097]]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3) 
model = kmeans.fit(X_std) 
labels = model.predict(X_std)
# Plot cluster membership
from matplotlib import pyplot
pyplot.scatter(data['popularity'], data['duration_ms'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['year'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['acousticness'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['energy'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['instrumentalness'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['liveness'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['loudness'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['speechiness'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['mode'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['key'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['explicit'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['NumArtists'], c=labels, cmap='rainbow')

# %%
pyplot.scatter(data['popularity'], data['NameLength'], c=labels, cmap='rainbow')

# %% [markdown]
# ### DBSCAN

# %%
import numpy as np 
from sklearn.cluster import DBSCAN 
from sklearn import metrics
from sklearn.preprocessing import StandardScaler 
import matplotlib.pyplot as plt 

from sklearn.datasets import make_blobs, make_circles, make_moons
from sklearn.cluster import KMeans

# %%
X = data.drop(columns='popularity')
y = data['popularity']

# %%
X = StandardScaler().fit_transform(X)

# %%
optimal_k = 3
kmeans = KMeans(n_clusters = optimal_k, init = 'k-means++')
y_kmeans = kmeans.fit_predict(X)

# %%
'''
db = DBSCAN(eps=0.3, min_samples=10).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
'''
# Out:
# '\ndb = DBSCAN(eps=0.3, min_samples=10).fit(X)\ncore_samples_mask = np.zeros_like(db.labels_, dtype=bool)\ncore_samples_mask[db.core_sample_indices_] = True\nlabels = db.labels_\n\n# Number of clusters in labels, ignoring noise if present.\nn_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)\nn_noise_ = list(labels).count(-1)\n'

# %%
######## number of cluster = 3 ##############
######## use this one ###########
import numpy as np 
from sklearn.cluster import DBSCAN 
from sklearn import metrics
from sklearn.preprocessing import StandardScaler 
import matplotlib.pyplot as plt 

from sklearn.datasets import make_blobs, make_circles, make_moons
from sklearn.cluster import KMeans

# Compute DBSCAN
db = DBSCAN(eps=0.45, min_samples=5).fit(X_std)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
print("numebr of clusters:" + str(n_clusters_))
# Out:
# numebr of clusters:3

# %%
fig, (ax1, ax2) = plt.subplots(ncols =2)
# fig, (ax3) = plt.subplots(ncols =1)
fig.set_figheight(10)
fig.set_figwidth(30)

colours = ['red','blue','green','yellow','cyan','magenta','orange','aqua','pink']
for i in range(optimal_k):
    ax1.scatter(X[y_kmeans == i, 0], X[y_kmeans == i, 1], s = 100, c = colours[i], label = 'Group'+str(i+1))

# Plotting the centroids of the clusters
ax1.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'black', label = 'Centroids')
ax1.set_title("K Means clustering")
ax1.legend()


# Black removed and is used for noise instead.
unique_labels = set(labels)
for k, col in zip(unique_labels, colours):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)
    
    xy = X[class_member_mask & core_samples_mask]
    ax2.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=(col),
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    ax2.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=(col),
             markeredgecolor='k', markersize=6)

ax2.set_title('DBSCAN with Estimated number of clusters: %d' % n_clusters_)
# Out:
# Text(0.5, 1.0, 'DBSCAN with Estimated number of clusters: 3')

# %% [markdown]
# ## PCA

# %%
pip install bioinfokit
# Out:
# Collecting bioinfokit
#   Downloading bioinfokit-2.0.8.tar.gz (84 kB)
#      |████████████████████████████████| 84 kB 413 kB/s eta 0:00:01
# Requirement already satisfied: pandas in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from bioinfokit) (1.2.4)
# Requirement already satisfied: numpy in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from bioinfokit) (1.20.1)
# Requirement already satisfied: matplotlib in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from bioinfokit) (3.5.1)
# Requirement already satisfied: scipy in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from bioinfokit) (1.4.1)
# Requirement already satisfied: scikit-learn in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from bioinfokit) (1.0.1)
# Requirement already satisfied: seaborn in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from bioinfokit) (0.11.1)
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-0.11.6.tar.gz (29 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: statsmodels in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from bioinfokit) (0.12.2)
# Collecting textwrap3
#   Downloading textwrap3-0.9.2-py2.py3-none-any.whl (12 kB)
# Collecting adjustText
#   Downloading adjustText-0.7.3.tar.gz (7.5 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->bioinfokit) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->bioinfokit) (2.8.1)
# Requirement already satisfied: packaging>=20.0 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->bioinfokit) (20.9)
# Requirement already satisfied: pillow>=6.2.0 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->bioinfokit) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->bioinfokit) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->bioinfokit) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->bioinfokit) (4.28.3)
# Requirement already satisfied: six in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->bioinfokit) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from pandas->bioinfokit) (2021.1)
# Requirement already satisfied: joblib>=0.11 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->bioinfokit) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->bioinfokit) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in /Users/sandychen/opt/anaconda3/lib/python3.8/site-packages (from statsmodels->bioinfokit) (0.5.1)
# Building wheels for collected packages: bioinfokit, adjustText, matplotlib-venn
#   Building wheel for bioinfokit (setup.py) ... done
#   Created wheel for bioinfokit: filename=bioinfokit-2.0.8-py3-none-any.whl size=56748 sha256=2966713383ce90a4af9b54c9ca3f97517a34d8d662e0f5712da934667baec310
#   Stored in directory: /Users/sandychen/Library/Caches/pip/wheels/40/b8/82/23dd1b441e2c834181d4c595cff79f091212eb2c482e0550e2
#   Building wheel for adjustText (setup.py) ... done
#   Created wheel for adjustText: filename=adjustText-0.7.3-py3-none-any.whl size=7098 sha256=978db50d41e125267293812dabd434b5f273898ce61c8faa8e4307083f903241
#   Stored in directory: /Users/sandychen/Library/Caches/pip/wheels/06/b2/e0/b239bd2c0ff89b98c4f0c86a63e7059f38a8dfaf6df2641c63
#   Building wheel for matplotlib-venn (setup.py) ... done
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-0.11.6-py3-none-any.whl size=32062 sha256=b6107577064f651f39004b66a7c3b3aa4010046ec5d4a51f26c5f82c537bbc01
#   Stored in directory: /Users/sandychen/Library/Caches/pip/wheels/82/e4/64/dd790d424818bc2f59c11471a1eee5dc8cfcd3f8ee8c4812fa
# Successfully built bioinfokit adjustText matplotlib-venn
# Installing collected packages: textwrap3, tabulate, matplotlib-venn, adjustText, bioinfokit
# Successfully installed adjustText-0.7.3 bioinfokit-2.0.8 matplotlib-venn-0.11.6 tabulate-0.8.9 textwrap3-0.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from bioinfokit.visuz import cluster

# %%
X = data.drop(columns='popularity')
y = data['popularity']

# %%
from sklearn.decomposition import PCA 
pca = PCA(n_components=10) 
pca.fit(X)
pca.explained_variance_ratio_
# Out:
# array([9.99999888e-01, 6.70045496e-08, 4.22141921e-08, 1.61949388e-09,
#        8.42323461e-10, 6.25281581e-10, 4.73425218e-11, 1.39431415e-11,
#        6.96384739e-12, 5.05498499e-12])

# %%
X_st =  StandardScaler().fit_transform(X)
pca_out = PCA().fit(X_st)

# %%
loadings = pca_out.components_

# %%
pca_out.explained_variance_
# Out:
# array([3.74242568, 1.65155831, 1.5267745 , 1.1982863 , 1.09907043,
#        1.0158912 , 0.92650874, 0.91065985, 0.83549757, 0.74992217,
#        0.61982712, 0.5188597 , 0.47779628, 0.34065092, 0.26468508,
#        0.12168068])

# %%
# get biplot
pca_scores = PCA().fit_transform(X_st)
cluster.biplot(cscore=pca_scores, loadings=loadings, labels=X.columns.values, var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
    var2=round(pca_out.explained_variance_ratio_[1]*100, 2), colorlist='target')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4220             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4221                 colors = mcolors.to_rgba_array(c)
#    4222             except (TypeError, ValueError) as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     376     else:
# --> 377         rgba = np.array([to_rgba(cc) for cc in c])
#     378
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     376     else:
# --> 377         rgba = np.array([to_rgba(cc) for cc in c])
#     378
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     186     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 187         rgba = _to_rgba_no_colorcycle(c, alpha)
#     188         try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     268     if not np.iterable(c):
# --> 269         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     270     if len(c) not in [3, 4]:
#
# ValueError: Invalid RGBA argument: 0.0
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-4e86ff3a6a08> in <module>
#       1 # get biplot
#       2 pca_scores = PCA().fit_transform(X_st)
# ----> 3 cluster.biplot(cscore=pca_scores, loadings=loadings, labels=X.columns.values, var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
#       4     var2=round(pca_out.explained_variance_ratio_[1]*100, 2), colorlist='target')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bioinfokit/visuz.py in biplot(cscore, loadings, labels, var1, var2, var3, axlabelfontsize, axlabelfontname, figtype, r, show, markerdot, dotsize, valphadot, colordot, arrowcolor, valphaarrow, arrowlinestyle, arrowlinewidth, centerlines, colorlist, legendpos, datapoints, dim, theme)
#    1856                         #                alpha=valphadot, marker=markerdot)
#    1857                         # plt.legend(handles=s.legend_elements()[0], labels=list(unique_class))
# -> 1858                         s = plt.scatter(cscore[:, 0] * xscale, cscore[:, 1] * yscale, c=color_result_num, s=dotsize,
#    1859                                     alpha=valphadot, marker=markerdot)
#    1860                         plt.legend(handles=s.legend_elements()[0], labels=list(unique_class), loc=legendpos)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4385             orig_edgecolor = kwargs.get('edgecolor', None)
#    4386         c, colors, edgecolors = \
# -> 4387             self._parse_scatter_color_args(
#    4388                 c, edgecolors, kwargs, x.size,
#    4389                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4225                 else:
#    4226                     if not valid_shape:
# -> 4227                         raise invalid_shape_exception(c.size, xsize) from err
#    4228                     # Both the mapping *and* the RGBA conversion failed: pretty
#    4229                     # severe failure => one may appreciate a verbose feedback.
#
# ValueError: 'c' argument has 6 elements, which is inconsistent with 'x' and 'y' with size 169260.

# %%
pip install psynlig

# %%
from psynlig import pca_2d_scores
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %%
X = data.drop(columns='popularity')
y = data['popularity']

# %%
pca = PCA()
scores = pca.fit_transform(X)

# %%
loading_settings = {
    'add_text': True,
    'add_legend': False,
    'biplot': True,
    'text': {
        'fontsize': 'x-large',
        'alpha': 0.8,
        'outline': {'linewidth': 1.5}
    },
}

xvars = ['duration_ms',	'year',	'acousticness',	'danceability',	'energy',	'instrumentalness',	'liveness',	'loudness',	'speechiness',	'tempo',	'valence',	'mode',	'key',	'explicit',	'NumArtists',	'NameLength']
class_data = data['popularity']
class_names = dict(enumerate(data['popularity']))
X = scale(X)

# %%
pca_2d_scores(
    pca,
    scores,
    xvars=xvars,
    class_data=class_data,
    class_names=class_names,
    select_components={(1, 2)},
    loading_settings=loading_settings,
    s=150,
    alpha=.5,
    cmap_loadings='plasma',
)

# %%
data_set = load_breast_cancer()
data = pd.DataFrame(data_set['data'], columns=data_set['feature_names'])
xvars = [
    'mean radius',
    'mean texture',
    'mean perimeter',
    'mean area',
    'mean smoothness',
    'mean compactness',
    'mean concavity',
    'mean concave points',
    'mean symmetry',
    'mean fractal dimension',
]
data = data[xvars]
class_data = data_set['target']
class_names = dict(enumerate(data_set['target_names']))
data = scale(data)

pcloading_settings = {
    'add_text': True,
    'add_legend': False,
    'biplot': True,
    'text': {
        'fontsize': 'x-large',
        'alpha': 0.8,
        'outline': {'linewidth': 1.5}
    },
}a = PCA()
scores = pca.fit_transform(data)



pca_2d_scores(
    pca,
    scores,
    xvars=xvars,
    class_data=class_data,
    class_names=class_names,
    select_components={(1, 2)},
    loading_settings=loading_settings,
    s=150,
    alpha=.5,
    cmap_loadings='plasma',
)

loading_settings = {
    'add_text': False,
    'add_legend': True,
    'biplot': True,
}

pca_2d_scores(
    pca,
    scores,
    xvars=xvars,
    class_data=class_data,
    class_names=class_names,
    select_components={(1, 2)},
    loading_settings=loading_settings,
    s=150,
    alpha=.5,
    cmap_class='Spectral',
)
plt.show()

# %% [markdown]
# ## Recommendation engine based on KNN

# %% [markdown]
# ## KNN Recommendation Based on song title

# %%
import numpy as np
from sklearn.neighbors import NearestNeighbors

# %%
def check_title_index(data):
    title = input('Please in put a song you like ヽ(○´∀`)ﾉ♪')
    warning = 'The song you want to search does not exist in Spotify dataset. Please Try another one :('
    
    for i in range(len(data['name'])):
        if title.lower() == data['name'].values[i].lower():
            index = i
            break
        else:
            index = 'none'
    if index != 'none':
        return index
    if index == 'none':
        return warning

# %%
def knn_recommendation(random_status,data,num_recommendation):
    data_num = data.iloc[:,2:]
    data_matrix = np.matrix(data_num.values) 
    knn = NearestNeighbors(metric = 'cosine', algorithm='auto', leaf_size=30, n_neighbors=5, p=2,radius=1.0)
    knn.fit(data_matrix)
    
    if random_status == True:
        query_index = np.random.choice(data.shape[0])
    else:
        #title = input('Please in put a song you like ヽ(○´∀`)ﾉ♪')
        ind = check_title_index(data)
        if type(ind) == int:
            query_index = ind
        else:
            return ind
     
    distances, indices = knn.kneighbors(data_matrix[query_index,:], n_neighbors=num_recommendation+1)
    indices = indices[0]
    indices = list(indices)
    indices.remove(query_index)
    print('Here are',num_recommendation,'recommended songs for you :)')
    for i in range(len(indices)):
        song_name = data.iloc[indices[i],:]['name']
        artists_lis = data.iloc[indices[i],:].artists
        artists_lis = ','.join(artists_lis)
        year = data.iloc[indices[i],:].year
        print('#',i+1)
        print('Song Name:',song_name)
        print('Artist Name:', artists_lis)
        print('The year of publication is:',year)

# %%
knn_recommendation(False,data2,3)
